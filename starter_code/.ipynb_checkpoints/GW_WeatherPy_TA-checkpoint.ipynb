# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 591

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
#*****TEST only******
url = url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key
print(url)
# city_url = url + "&q=" + "hobart"
# json_info = requests.get(city_url).json()
# print(json_info)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=3f49a59ca6688ccae813067704506fbd

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key
# url = "https://api.openweathermap.org/data/2.5/weather?q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    # city_url = f'{url}{city}&units=metric&appid={weather_api_key}'
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response_json = requests.get(city_url).json()
        # json_info = requests.get(city_url).json()
        # city_weather = response_json["weather"]
        

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response_json["coord"]["lat"]
        city_lng = response_json["coord"]["lon"]
        city_max_temp = response_json["main"]["temp_max"]
        city_humidity = response_json["main"]["humidity"]
        city_clouds = response_json["clouds"]["all"]
        city_wind = response_json["wind"]["speed"]
        city_country = response_json["sys"]["country"]
        city_date = response_json["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        # city_data.append({
        #                   "Lat": city_lat, 
        #                   "Lng": city_lng, 
        #                   "Max Temp": city_max_temp,
        #                   "Humidity": city_humidity,
        #                   "Cloudiness": city_clouds,
        #                   "Wind Speed": city_wind,
        #                   "Country": city_country,
        #                   "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | saint-philippe
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | airai
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | anadyr
# Processing Record 12 of Set 1 | severo-kurilsk
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | bambous virieux
# Processing Record 15 of Set 1 | geraldton
# Processing Record 16 of Set 1 | faanui
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | sao filipe
# Processing Record 19 of Set 1 | lagoa
# Processing Record 20 of Set 1 | clyde river
# Processing Record 21 of Set 1 | poum
# Processing Record 22 of Set 1 | nikolskoye
# Processing Record 23 of Set 1 | namibe
# Processing Record 24 of Set 1 | alice springs
# Processing Record 25 of Set 1 | nelson bay
# Processing Record 26 of Set 1 | ghatanji
# Processing Record 27 of Set 1 | hami
# Processing Record 28 of Set 1 | mar del plata
# Processing Record 29 of Set 1 | manicore
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | hofn
# Processing Record 32 of Set 1 | saint george
# Processing Record 33 of Set 1 | raca
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | radishchevo
# Processing Record 36 of Set 1 | karauzyak
# City not found. Skipping...
# Processing Record 37 of Set 1 | taunggyi
# Processing Record 38 of Set 1 | talaya
# Processing Record 39 of Set 1 | vestmannaeyjar
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | sahuaripa
# Processing Record 42 of Set 1 | northview
# Processing Record 43 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | burnie
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | evensk
# Processing Record 49 of Set 1 | cherskiy
# Processing Record 50 of Set 1 | hakkari
# Processing Record 0 of Set 2 | puerto ayora
# Processing Record 1 of Set 2 | inta
# Processing Record 2 of Set 2 | butaritari
# Processing Record 3 of Set 2 | hamilton
# Processing Record 4 of Set 2 | ponta do sol
# Processing Record 5 of Set 2 | pisco
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 2 | tomatlan
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | east london
# Processing Record 11 of Set 2 | saint anthony
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | merauke
# Processing Record 14 of Set 2 | rudnogorsk
# Processing Record 15 of Set 2 | ostrovnoy
# Processing Record 16 of Set 2 | bogorodskoye
# Processing Record 17 of Set 2 | bluff
# Processing Record 18 of Set 2 | hilo
# Processing Record 19 of Set 2 | amalapuram
# Processing Record 20 of Set 2 | kargasok
# Processing Record 21 of Set 2 | samarai
# Processing Record 22 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 23 of Set 2 | bengkulu
# Processing Record 24 of Set 2 | lismore
# Processing Record 25 of Set 2 | sola
# Processing Record 26 of Set 2 | hithadhoo
# Processing Record 27 of Set 2 | labuhan
# Processing Record 28 of Set 2 | nicolas bravo
# Processing Record 29 of Set 2 | mushie
# Processing Record 30 of Set 2 | port alfred
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | rocha
# Processing Record 33 of Set 2 | georgetown
# Processing Record 34 of Set 2 | tuktoyaktuk
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | chabahar
# Processing Record 37 of Set 2 | zhezkazgan
# Processing Record 38 of Set 2 | kaitangata
# Processing Record 39 of Set 2 | tocopilla
# Processing Record 40 of Set 2 | bredasdorp
# Processing Record 41 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 2 | ugoofaaru
# Processing Record 43 of Set 2 | louis trichardt
# Processing Record 44 of Set 2 | jamestown
# Processing Record 45 of Set 2 | ilulissat
# Processing Record 46 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 2 | sulangan
# Processing Record 48 of Set 2 | ribeira grande
# Processing Record 49 of Set 2 | katsuura
# Processing Record 0 of Set 3 | dikson
# Processing Record 1 of Set 3 | broome
# Processing Record 2 of Set 3 | boshnyakovo
# Processing Record 3 of Set 3 | san jose
# Processing Record 4 of Set 3 | hovd
# Processing Record 5 of Set 3 | severo-yeniseyskiy
# Processing Record 6 of Set 3 | hambantota
# Processing Record 7 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 3 | kosa
# Processing Record 9 of Set 3 | hobyo
# Processing Record 10 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 11 of Set 3 | klaksvik
# Processing Record 12 of Set 3 | reefton
# City not found. Skipping...
# Processing Record 13 of Set 3 | arraial do cabo
# Processing Record 14 of Set 3 | beringovskiy
# Processing Record 15 of Set 3 | port pirie
# Processing Record 16 of Set 3 | nyimba
# Processing Record 17 of Set 3 | la ronge
# Processing Record 18 of Set 3 | pantai remis
# Processing Record 19 of Set 3 | ishigaki
# Processing Record 20 of Set 3 | seoul
# Processing Record 21 of Set 3 | naze
# Processing Record 22 of Set 3 | carnarvon
# Processing Record 23 of Set 3 | linchuan
# City not found. Skipping...
# Processing Record 24 of Set 3 | kodiak
# Processing Record 25 of Set 3 | bac lieu
# Processing Record 26 of Set 3 | kysyl-syr
# Processing Record 27 of Set 3 | ancud
# Processing Record 28 of Set 3 | egvekinot
# Processing Record 29 of Set 3 | trofors
# Processing Record 30 of Set 3 | linqiong
# Processing Record 31 of Set 3 | tabou
# Processing Record 32 of Set 3 | gat
# Processing Record 33 of Set 3 | santa luzia
# Processing Record 34 of Set 3 | palu
# Processing Record 35 of Set 3 | karachi
# Processing Record 36 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 3 | guerrero negro
# Processing Record 38 of Set 3 | victoria
# Processing Record 39 of Set 3 | narsaq
# Processing Record 40 of Set 3 | hearst
# Processing Record 41 of Set 3 | tasiilaq
# Processing Record 42 of Set 3 | cidreira
# Processing Record 43 of Set 3 | gamba
# Processing Record 44 of Set 3 | cabo san lucas
# Processing Record 45 of Set 3 | dudinka
# Processing Record 46 of Set 3 | port elizabeth
# Processing Record 47 of Set 3 | oranjestad
# Processing Record 48 of Set 3 | brae
# Processing Record 49 of Set 3 | archidona
# Processing Record 0 of Set 4 | ossora
# Processing Record 1 of Set 4 | kiama
# Processing Record 2 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 4 | waingapu
# Processing Record 4 of Set 4 | ravar
# Processing Record 5 of Set 4 | iqaluit
# Processing Record 6 of Set 4 | amahai
# Processing Record 7 of Set 4 | garoua boulai
# Processing Record 8 of Set 4 | kutum
# Processing Record 9 of Set 4 | aykhal
# Processing Record 10 of Set 4 | dingle
# Processing Record 11 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 4 | tuban
# Processing Record 13 of Set 4 | luderitz
# Processing Record 14 of Set 4 | sorland
# Processing Record 15 of Set 4 | porto walter
# Processing Record 16 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 4 | atar
# Processing Record 18 of Set 4 | tautira
# Processing Record 19 of Set 4 | ketchikan
# Processing Record 20 of Set 4 | qaanaaq
# Processing Record 21 of Set 4 | lata
# Processing Record 22 of Set 4 | provideniya
# Processing Record 23 of Set 4 | mwinilunga
# Processing Record 24 of Set 4 | saldanha
# Processing Record 25 of Set 4 | sioux lookout
# Processing Record 26 of Set 4 | ahipara
# Processing Record 27 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 4 | olga
# Processing Record 29 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 4 | jumla
# Processing Record 31 of Set 4 | kindu
# Processing Record 32 of Set 4 | barrow
# Processing Record 33 of Set 4 | luanda
# Processing Record 34 of Set 4 | sao joao da barra
# Processing Record 35 of Set 4 | usinsk
# Processing Record 36 of Set 4 | gunjur
# Processing Record 37 of Set 4 | barra patuca
# Processing Record 38 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 4 | hollister
# Processing Record 40 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 4 | port-cartier
# Processing Record 42 of Set 4 | tura
# Processing Record 43 of Set 4 | ginda
# Processing Record 44 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 4 | orotukan
# Processing Record 46 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 47 of Set 4 | havre-saint-pierre
# Processing Record 48 of Set 4 | puerto carreno
# Processing Record 49 of Set 4 | campbellton
# Processing Record 0 of Set 5 | puerto escondido
# Processing Record 1 of Set 5 | maniitsoq
# Processing Record 2 of Set 5 | zhigansk
# Processing Record 3 of Set 5 | upata
# Processing Record 4 of Set 5 | mahebourg
# Processing Record 5 of Set 5 | vila velha
# Processing Record 6 of Set 5 | safaga
# Processing Record 7 of Set 5 | nevelsk
# Processing Record 8 of Set 5 | yerofey pavlovich
# Processing Record 9 of Set 5 | nhulunbuy
# Processing Record 10 of Set 5 | nyurba
# Processing Record 11 of Set 5 | arlit
# Processing Record 12 of Set 5 | polovinnoye
# Processing Record 13 of Set 5 | alyangula
# Processing Record 14 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 5 | ratne
# Processing Record 16 of Set 5 | ilhabela
# Processing Record 17 of Set 5 | umm bab
# Processing Record 18 of Set 5 | paamiut
# Processing Record 19 of Set 5 | daman
# Processing Record 20 of Set 5 | labytnangi
# Processing Record 21 of Set 5 | lompoc
# Processing Record 22 of Set 5 | coxim
# Processing Record 23 of Set 5 | saskylakh
# Processing Record 24 of Set 5 | surt
# Processing Record 25 of Set 5 | terrace
# Processing Record 26 of Set 5 | portland
# Processing Record 27 of Set 5 | thompson
# Processing Record 28 of Set 5 | morondava
# Processing Record 29 of Set 5 | bonthe
# Processing Record 30 of Set 5 | pevek
# Processing Record 31 of Set 5 | vaitape
# Processing Record 32 of Set 5 | noumea
# Processing Record 33 of Set 5 | acurenam
# Processing Record 34 of Set 5 | payakumbuh
# Processing Record 35 of Set 5 | pafos
# Processing Record 36 of Set 5 | souillac
# Processing Record 37 of Set 5 | severnoye
# Processing Record 38 of Set 5 | goderich
# Processing Record 39 of Set 5 | hokitika
# Processing Record 40 of Set 5 | mount gambier
# Processing Record 41 of Set 5 | kruisfontein
# Processing Record 42 of Set 5 | nara
# Processing Record 43 of Set 5 | narasannapeta
# Processing Record 44 of Set 5 | san patricio
# Processing Record 45 of Set 5 | bilibino
# Processing Record 46 of Set 5 | ghanzi
# Processing Record 47 of Set 5 | hun
# Processing Record 48 of Set 5 | kirksville
# Processing Record 49 of Set 5 | marsaxlokk
# Processing Record 0 of Set 6 | yeppoon
# Processing Record 1 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 2 of Set 6 | erenhot
# Processing Record 3 of Set 6 | marrakesh
# Processing Record 4 of Set 6 | faya
# Processing Record 5 of Set 6 | alofi
# Processing Record 6 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 6 | aranda de duero
# Processing Record 8 of Set 6 | kathu
# Processing Record 9 of Set 6 | norman wells
# Processing Record 10 of Set 6 | marbella
# Processing Record 11 of Set 6 | victor harbor
# Processing Record 12 of Set 6 | perote
# Processing Record 13 of Set 6 | wenatchee
# Processing Record 14 of Set 6 | torbay
# Processing Record 15 of Set 6 | hasaki
# Processing Record 16 of Set 6 | upernavik
# Processing Record 17 of Set 6 | avarua
# Processing Record 18 of Set 6 | wasilla
# Processing Record 19 of Set 6 | recanati
# Processing Record 20 of Set 6 | galgani
# City not found. Skipping...
# Processing Record 21 of Set 6 | leningradskiy
# Processing Record 22 of Set 6 | bay roberts
# Processing Record 23 of Set 6 | nangong
# Processing Record 24 of Set 6 | beaverlodge
# Processing Record 25 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 26 of Set 6 | staryy nadym
# Processing Record 27 of Set 6 | havoysund
# Processing Record 28 of Set 6 | kahului
# Processing Record 29 of Set 6 | belyy yar
# Processing Record 30 of Set 6 | yamada
# Processing Record 31 of Set 6 | half moon bay
# Processing Record 32 of Set 6 | aklavik
# Processing Record 33 of Set 6 | kedrovyy
# Processing Record 34 of Set 6 | ye
# City not found. Skipping...
# Processing Record 35 of Set 6 | rundu
# Processing Record 36 of Set 6 | chokurdakh
# Processing Record 37 of Set 6 | griffith
# Processing Record 38 of Set 6 | barra dos coqueiros
# Processing Record 39 of Set 6 | onokhoy
# Processing Record 40 of Set 6 | vanimo
# Processing Record 41 of Set 6 | constitucion
# Processing Record 42 of Set 6 | kurilsk
# Processing Record 43 of Set 6 | dawlatabad
# Processing Record 44 of Set 6 | aginskoye
# Processing Record 45 of Set 6 | lipari
# Processing Record 46 of Set 6 | buraydah
# Processing Record 47 of Set 6 | grindavik
# Processing Record 48 of Set 6 | mopipi
# Processing Record 49 of Set 6 | karratha
# Processing Record 0 of Set 7 | coihaique
# Processing Record 1 of Set 7 | banepa
# Processing Record 2 of Set 7 | marmashen
# Processing Record 3 of Set 7 | west bay
# Processing Record 4 of Set 7 | castanos
# Processing Record 5 of Set 7 | vila franca do campo
# Processing Record 6 of Set 7 | batagay
# Processing Record 7 of Set 7 | veracruz
# Processing Record 8 of Set 7 | kirensk
# Processing Record 9 of Set 7 | vereya
# Processing Record 10 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 7 | inhambane
# Processing Record 12 of Set 7 | novikovo
# Processing Record 13 of Set 7 | bubaque
# Processing Record 14 of Set 7 | zakharovo
# Processing Record 15 of Set 7 | arcata
# Processing Record 16 of Set 7 | codrington
# Processing Record 17 of Set 7 | tuatapere
# Processing Record 18 of Set 7 | treia
# Processing Record 19 of Set 7 | saint-francois
# Processing Record 20 of Set 7 | pincher creek
# Processing Record 21 of Set 7 | elko
# Processing Record 22 of Set 7 | te anau
# Processing Record 23 of Set 7 | fairbanks
# Processing Record 24 of Set 7 | simpang
# Processing Record 25 of Set 7 | novorudnyy
# Processing Record 26 of Set 7 | vardo
# Processing Record 27 of Set 7 | vallenar
# Processing Record 28 of Set 7 | juneau
# Processing Record 29 of Set 7 | vila
# Processing Record 30 of Set 7 | uvira
# Processing Record 31 of Set 7 | pacific grove
# Processing Record 32 of Set 7 | salalah
# Processing Record 33 of Set 7 | charcas
# Processing Record 34 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 35 of Set 7 | sao felix do xingu
# Processing Record 36 of Set 7 | areia branca
# Processing Record 37 of Set 7 | qaqortoq
# Processing Record 38 of Set 7 | lamu
# Processing Record 39 of Set 7 | markkleeberg
# Processing Record 40 of Set 7 | dire dawa
# Processing Record 41 of Set 7 | lekoni
# Processing Record 42 of Set 7 | milkovo
# Processing Record 43 of Set 7 | barranca
# Processing Record 44 of Set 7 | nuuk
# Processing Record 45 of Set 7 | tual
# Processing Record 46 of Set 7 | santa cruz cabralia
# Processing Record 47 of Set 7 | monywa
# Processing Record 48 of Set 7 | eagle
# Processing Record 49 of Set 7 | lakatoro
# Processing Record 0 of Set 8 | artvin
# Processing Record 1 of Set 8 | marataizes
# Processing Record 2 of Set 8 | port macquarie
# Processing Record 3 of Set 8 | portree
# Processing Record 4 of Set 8 | paka
# Processing Record 5 of Set 8 | isangel
# Processing Record 6 of Set 8 | cap malheureux
# Processing Record 7 of Set 8 | ola
# Processing Record 8 of Set 8 | lumberton
# Processing Record 9 of Set 8 | constantine
# Processing Record 10 of Set 8 | falciu
# Processing Record 11 of Set 8 | marang
# Processing Record 12 of Set 8 | walvis bay
# Processing Record 13 of Set 8 | roebourne
# Processing Record 14 of Set 8 | fortuna
# Processing Record 15 of Set 8 | deer lake
# Processing Record 16 of Set 8 | tumut
# Processing Record 17 of Set 8 | khatanga
# Processing Record 18 of Set 8 | mirnyy
# Processing Record 19 of Set 8 | viedma
# Processing Record 20 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 8 | podhum
# Processing Record 22 of Set 8 | lebu
# Processing Record 23 of Set 8 | pandan
# Processing Record 24 of Set 8 | churapcha
# Processing Record 25 of Set 8 | shahr-e babak
# Processing Record 26 of Set 8 | nizhniy ingash
# Processing Record 27 of Set 8 | beloha
# Processing Record 28 of Set 8 | nambucca heads
# Processing Record 29 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 8 | nanortalik
# Processing Record 31 of Set 8 | ulundi
# Processing Record 32 of Set 8 | fort nelson
# Processing Record 33 of Set 8 | tal
# Processing Record 34 of Set 8 | padang
# Processing Record 35 of Set 8 | ippy
# Processing Record 36 of Set 8 | yining
# Processing Record 37 of Set 8 | shinjo
# Processing Record 38 of Set 8 | laguna de perlas
# Processing Record 39 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 40 of Set 8 | north bend
# Processing Record 41 of Set 8 | klembivka
# Processing Record 42 of Set 8 | sonoita
# Processing Record 43 of Set 8 | cartagena
# Processing Record 44 of Set 8 | svetlaya
# Processing Record 45 of Set 8 | antofagasta
# Processing Record 46 of Set 8 | conakry
# Processing Record 47 of Set 8 | gazanjyk
# Processing Record 48 of Set 8 | dombas
# Processing Record 49 of Set 8 | sur
# Processing Record 0 of Set 9 | rawa mazowiecka
# Processing Record 1 of Set 9 | puerto lempira
# Processing Record 2 of Set 9 | tuy hoa
# Processing Record 3 of Set 9 | san andres
# Processing Record 4 of Set 9 | prince rupert
# Processing Record 5 of Set 9 | mayo
# Processing Record 6 of Set 9 | mayya
# Processing Record 7 of Set 9 | wilmington island
# Processing Record 8 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 9 | abasha
# Processing Record 10 of Set 9 | monrovia
# Processing Record 11 of Set 9 | rabo de peixe
# Processing Record 12 of Set 9 | chuy
# Processing Record 13 of Set 9 | menongue
# Processing Record 14 of Set 9 | bochnia
# Processing Record 15 of Set 9 | pleasant point
# Processing Record 16 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 18 of Set 9 | moquegua
# Processing Record 19 of Set 9 | honningsvag
# Processing Record 20 of Set 9 | lambarene
# Processing Record 21 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 9 | belmonte
# Processing Record 23 of Set 9 | haines junction
# Processing Record 24 of Set 9 | amapa
# Processing Record 25 of Set 9 | mahanoro
# Processing Record 26 of Set 9 | maridi
# Processing Record 27 of Set 9 | talnakh
# Processing Record 28 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 9 | praya
# Processing Record 30 of Set 9 | deder
# Processing Record 31 of Set 9 | korhogo
# Processing Record 32 of Set 9 | bagli
# Processing Record 33 of Set 9 | freeport
# Processing Record 34 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 35 of Set 9 | marquette
# Processing Record 36 of Set 9 | puerto narino
# Processing Record 37 of Set 9 | sisimiut
# Processing Record 38 of Set 9 | doha
# Processing Record 39 of Set 9 | pangnirtung
# Processing Record 40 of Set 9 | roald
# Processing Record 41 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 9 | camopi
# Processing Record 43 of Set 9 | ivanivka
# Processing Record 44 of Set 9 | sarangani
# Processing Record 45 of Set 9 | agucadoura
# Processing Record 46 of Set 9 | bandar-e anzali
# Processing Record 47 of Set 9 | bosaso
# Processing Record 48 of Set 9 | flinders
# Processing Record 49 of Set 9 | sokoni
# Processing Record 0 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 10 | cayenne
# Processing Record 2 of Set 10 | poya
# Processing Record 3 of Set 10 | manggar
# Processing Record 4 of Set 10 | chifeng
# Processing Record 5 of Set 10 | samdari
# Processing Record 6 of Set 10 | vilhena
# Processing Record 7 of Set 10 | yulara
# Processing Record 8 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 9 of Set 10 | coquimbo
# Processing Record 10 of Set 10 | taltal
# Processing Record 11 of Set 10 | malartic
# Processing Record 12 of Set 10 | shenjiamen
# Processing Record 13 of Set 10 | atambua
# Processing Record 14 of Set 10 | aswan
# Processing Record 15 of Set 10 | ovsyanka
# Processing Record 16 of Set 10 | port lincoln
# Processing Record 17 of Set 10 | mount isa
# Processing Record 18 of Set 10 | hirschaid
# Processing Record 19 of Set 10 | lubao
# Processing Record 20 of Set 10 | diffa
# Processing Record 21 of Set 10 | axim
# Processing Record 22 of Set 10 | moranbah
# Processing Record 23 of Set 10 | sao francisco
# Processing Record 24 of Set 10 | novobirilyussy
# Processing Record 25 of Set 10 | cravo norte
# Processing Record 26 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 10 | jalu
# Processing Record 28 of Set 10 | adrar
# Processing Record 29 of Set 10 | bathsheba
# Processing Record 30 of Set 10 | malindi
# Processing Record 31 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 32 of Set 10 | acireale
# Processing Record 33 of Set 10 | kieta
# Processing Record 34 of Set 10 | olafsvik
# Processing Record 35 of Set 10 | najran
# Processing Record 36 of Set 10 | tynda
# Processing Record 37 of Set 10 | matagami
# Processing Record 38 of Set 10 | absam
# Processing Record 39 of Set 10 | tazovskiy
# Processing Record 40 of Set 10 | henties bay
# Processing Record 41 of Set 10 | yuanping
# Processing Record 42 of Set 10 | mecca
# Processing Record 43 of Set 10 | nieuw amsterdam
# Processing Record 44 of Set 10 | santa maria
# Processing Record 45 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 10 | kirakira
# Processing Record 47 of Set 10 | la fleche
# Processing Record 48 of Set 10 | vostok
# Processing Record 49 of Set 10 | bage
# Processing Record 0 of Set 11 | farmington
# Processing Record 1 of Set 11 | riyadh
# Processing Record 2 of Set 11 | arroyo
# Processing Record 3 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 11 | san simon de la laguna
# Processing Record 5 of Set 11 | vetlanda
# Processing Record 6 of Set 11 | linjiang
# Processing Record 7 of Set 11 | kuruman
# Processing Record 8 of Set 11 | sivas
# Processing Record 9 of Set 11 | san policarpo
# Processing Record 10 of Set 11 | auki
# Processing Record 11 of Set 11 | salciile
# Processing Record 12 of Set 11 | kiunga
# Processing Record 13 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 11 | aberystwyth
# Processing Record 15 of Set 11 | lar
# Processing Record 16 of Set 11 | cabra
# Processing Record 17 of Set 11 | dosso
# Processing Record 18 of Set 11 | kavieng
# Processing Record 19 of Set 11 | tatawin
# Processing Record 20 of Set 11 | nichinan
# Processing Record 21 of Set 11 | santa isabel do rio negro
# Processing Record 22 of Set 11 | darhan
# Processing Record 23 of Set 11 | tarko-sale
# Processing Record 24 of Set 11 | salinas
# Processing Record 25 of Set 11 | at-bashi
# Processing Record 26 of Set 11 | aitape
# Processing Record 27 of Set 11 | ambon
# Processing Record 28 of Set 11 | kloulklubed
# Processing Record 29 of Set 11 | mahajanga
# Processing Record 30 of Set 11 | abrau-dyurso
# Processing Record 31 of Set 11 | lage
# Processing Record 32 of Set 11 | yinchuan
# Processing Record 33 of Set 11 | saint-augustin
# Processing Record 34 of Set 11 | macapa
# Processing Record 35 of Set 11 | baykit
# Processing Record 36 of Set 11 | ler
# Processing Record 37 of Set 11 | motygino
# Processing Record 38 of Set 11 | alikalia
# Processing Record 39 of Set 11 | srednekolymsk
# Processing Record 40 of Set 11 | lorengau
# Processing Record 41 of Set 11 | belle glade
# Processing Record 42 of Set 11 | karymskoye
# Processing Record 43 of Set 11 | soyo
# Processing Record 44 of Set 11 | davidson
# Processing Record 45 of Set 11 | siva
# Processing Record 46 of Set 11 | beni mazar
# Processing Record 47 of Set 11 | raudeberg
# Processing Record 48 of Set 11 | pattoki
# Processing Record 49 of Set 11 | pitimbu
# Processing Record 0 of Set 12 | chadiza
# Processing Record 1 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 12 | teguise
# Processing Record 3 of Set 12 | el alto
# Processing Record 4 of Set 12 | krasnoshchekovo
# Processing Record 5 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 6 of Set 12 | gigmoto
# Processing Record 7 of Set 12 | bandarbeyla
# Processing Record 8 of Set 12 | kollumerland
# City not found. Skipping...
# Processing Record 9 of Set 12 | husavik
# Processing Record 10 of Set 12 | rosarito
# Processing Record 11 of Set 12 | nikita
# Processing Record 12 of Set 12 | zhob
# Processing Record 13 of Set 12 | sao joao de pirabas
# Processing Record 14 of Set 12 | ponnani
# Processing Record 15 of Set 12 | yeniseysk
# Processing Record 16 of Set 12 | dianopolis
# City not found. Skipping...
# Processing Record 17 of Set 12 | kikwit
# Processing Record 18 of Set 12 | sosenskiy
# Processing Record 19 of Set 12 | sitka
# Processing Record 20 of Set 12 | dakar
# Processing Record 21 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 12 | boyabat
# Processing Record 23 of Set 12 | nasturelu
# Processing Record 24 of Set 12 | kerteh
# City not found. Skipping...
# Processing Record 25 of Set 12 | kulhudhuffushi
# Processing Record 26 of Set 12 | itarema
# Processing Record 27 of Set 12 | sept-iles
# Processing Record 28 of Set 12 | morgan city
# Processing Record 29 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 12 | thinadhoo
# Processing Record 31 of Set 12 | quang ngai
# Processing Record 32 of Set 12 | tilichiki
# Processing Record 33 of Set 12 | namatanai
# Processing Record 34 of Set 12 | mason city
# Processing Record 35 of Set 12 | talawdi
# City not found. Skipping...
# Processing Record 36 of Set 12 | boa vista
# Processing Record 37 of Set 12 | katobu
# Processing Record 38 of Set 12 | pemberton
# Processing Record 39 of Set 12 | kurdzhinovo
# Processing Record 40 of Set 12 | colchester
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          537
# Lat           537
# Lng           537
# Max Temp      537
# Humidity      537
# Cloudiness    537
# Wind Speed    537
# Country       537
# Date          537
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           tiksi  71.6872  128.8694    -31.51       100         100
# 1  saint-philippe -21.3585   55.7679     24.77        84          98
# 2          albany  42.6001  -73.9662     -8.21        55          39
# 3         rikitea -23.1203 -134.9692     25.87        77          20
# 4         mataura -46.1927  168.8643     15.80        99         100
#
#    Wind Speed Country        Date
# 0        1.11      RU  1675564602
# 1        3.99      RE  1675564603
# 2        2.48      US  1675564526
# 3        5.91      PF  1675564603
# 4        1.35      NZ  1675564604

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 tiksi  71.6872  128.8694    -31.51       100         100
# 1        saint-philippe -21.3585   55.7679     24.77        84          98
# 2                albany  42.6001  -73.9662     -8.21        55          39
# 3               rikitea -23.1203 -134.9692     25.87        77          20
# 4               mataura -46.1927  168.8643     15.80        99         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.11      RU  1675564602
# 1              3.99      RE  1675564603
# 2              2.48      US  1675564526
# 3              5.91      PF  1675564603
# 4              1.35      NZ  1675564604

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lat_temp_scatter = city_data_df.plot.scatter(x='Lat',y='Max Temp',c='Blue', figsize = (8,5))

# Incorporate the other graph properties
plt.grid()
plt.title("All city Latitudes vs Max Temperature")
plt.xlabel("Lat")
plt.ylabel("Max Temperature (C)")

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lat_humidity_scatter = city_data_df.plot.scatter(x='Lat',y='Humidity',c='Blue', figsize = (8,5))

# Incorporate the other graph properties
plt.grid()
plt.title("All city Latitudes vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lat_cloud_scatter = city_data_df.plot.scatter(x='Lat',y='Cloudiness',c='Blue', figsize = (8,5))

# Incorporate the other graph properties
plt.grid()
plt.title("All city Latitudes vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
lat_wind_scatter = city_data_df.plot.scatter(x='Lat',y='Wind Speed',c='Blue', figsize = (8,5))

# Incorporate the other graph properties
plt.grid()
plt.title("City Latitudes vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemis_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 tiksi  71.6872  128.8694    -31.51       100         100
# 2                albany  42.6001  -73.9662     -8.21        55          39
# 5                 kapaa  22.0752 -159.3190     24.18        81         100
# 8                anadyr  64.7500  177.4833    -29.72        69           0
# 9        severo-kurilsk  50.6789  156.1250     -1.68        67          98
#
#          Wind Speed Country        Date
# City_ID
# 0              1.11      RU  1675564602
# 2              2.48      US  1675564526
# 5              9.26      US  1675564604
# 8              4.00      RU  1675564605
# 9              3.10      RU  1675564605

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemis_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        saint-philippe -21.3585   55.7679     24.77        84          98
# 3               rikitea -23.1203 -134.9692     25.87        77          20
# 4               mataura -46.1927  168.8643     15.80        99         100
# 6                 airai  -8.9266  125.4092     19.68        77          96
# 7                 vaini -21.2000 -175.2000     30.09        74          75
#
#          Wind Speed Country        Date
# City_ID
# 1              3.99      RE  1675564603
# 3              5.91      PF  1675564603
# 4              1.35      NZ  1675564604
# 6              1.85      TL  1675564604
# 7              6.17      TO  1675564605

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is:-0.8697362665137829

# %%
# Linear regression on Southern Hemisphere
# Out:
# The r-value is:0.40648822019047404

# %% [markdown]
# **Discussion about the linear relationship:**

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# Out:
# The r-value is:0.28783211529559055

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
